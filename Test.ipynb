# %%
import numpy as np
import matplotlib.pyplot as plt

temp = np.load('temp_magnetization.npy')

# %%
norm  = [np.linalg.norm(temperature) for temperature in temp]

# %%
temp_range = np.linspace(0.01, 2, 40)
plt.plot(temp_range, np.array(norm)/16)
plt.xlabel('Temperature')
plt.ylabel('Magnetization')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib widget


fig = plt.figure()
ax = Axes3D(fig)
for i in range(len(temp)): 
    ax.scatter(temp[i][0], temp[i][1], temp[i][2])
# Out:
# /var/folders/g0/tzbfqcn53pv7bn0c224tbvdm0000gn/T/ipykernel_35786/2906256911.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
temp
# Out:
# array([[[  7.15352849],
#         [ -7.51987536],
#         [ 11.51610398]],
#
#        [[ -3.84479378],
#         [ -3.4877058 ],
#         [-14.96124776]],
#
#        [[ -0.30599416],
#         [  0.26892528],
#         [ 15.97592324]],
#
#        [[  4.4902043 ],
#         [ -6.72628836],
#         [ 13.36282137]],
#
#        [[ -5.15966272],
#         [-13.54893499],
#         [  5.32197485]],
#
#        [[-10.72520528],
#         [  9.78692395],
#         [ -1.06256548]],
#
#        [[ 14.3469738 ],
#         [ -1.77477426],
#         [ -4.53108017]],
#
#        [[  0.75992203],
#         [ 14.63188654],
#         [  3.18278774]],
#
#        [[  2.95318649],
#         [ -2.50080304],
#         [ 15.04774267]],
#
#        [[  7.85579805],
#         [ -0.61160936],
#         [-13.50058918]],
#
#        [[  0.28523661],
#         [ -0.82660264],
#         [ 15.86462218]],
#
#        [[  5.55165775],
#         [-10.48507024],
#         [  9.85907014]],
#
#        [[  4.40329931],
#         [ 12.96735029],
#         [  6.96880927]],
#
#        [[ -7.23833068],
#         [ -5.24457011],
#         [-12.575124  ]],
#
#        [[ -0.75332893],
#         [ -0.13452874],
#         [ 15.87272902]],
#
#        [[ -0.80754239],
#         [  0.47413354],
#         [ 15.91712456]],
#
#        [[  1.01719861],
#         [  0.70300035],
#         [ 15.90190704]],
#
#        [[ -2.28765057],
#         [ 12.61659812],
#         [  6.15894409]],
#
#        [[ -1.9121946 ],
#         [ -1.41829554],
#         [ 15.53463079]],
#
#        [[ -7.70747546],
#         [ -3.48014655],
#         [-13.38962673]]])
